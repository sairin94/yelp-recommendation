# %%
from pyathena import connect
import pandas as pd
import configparser
# Out:
# /Users/Shreya/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
config = configparser.ConfigParser()
config.read('access_keys_shreya.cfg') # reference the filepath to the configuration file
AWS_ACCESS_KEY = config.get('aws', 'aws_access_key')
AWS_SECRET_KEY = config.get('aws', 'aws_secret_key')
# Out:
# ---------------------------------------------------------------------------
# NoSectionError                            Traceback (most recent call last)
# <ipython-input-4-ce041bded96a> in <module>
#       1 config = configparser.ConfigParser()
#       2 config.read('access_keys_shreya.cfg') # reference the filepath to the configuration file
# ----> 3 AWS_ACCESS_KEY = config.get('aws', 'aws_access_key')
#       4 AWS_SECRET_KEY = config.get('aws', 'aws_secret_key')
#
# ~/anaconda3/lib/python3.7/configparser.py in get(self, section, option, raw, vars, fallback)
#     778         """
#     779         try:
# --> 780             d = self._unify_values(section, vars)
#     781         except NoSectionError:
#     782             if fallback is _UNSET:
#
# ~/anaconda3/lib/python3.7/configparser.py in _unify_values(self, section, vars)
#    1144         except KeyError:
#    1145             if section != self.default_section:
# -> 1146                 raise NoSectionError(section) from None
#    1147         # Update with the entry specific variables
#    1148         vardict = {}
#
# NoSectionError: No section: 'aws'

# %%
# from six.moves.urllib.parse import quote_plus
# from sqlalchemy.engine import create_engine

# SCHEMA_NAME = "yelp"
# S3_STAGING_DIR = "s3://sairin.yelp.dataset/dataset"
# AWS_REGION = "us-west-1"
# conn_str = (
#     "awsathena+rest://{aws_access_key_id}:{aws_secret_access_key}@"
#     "athena.{region_name}.amazonaws.com:443/"
#     "{schema_name}?s3_staging_dir={s3_staging_dir}&work_group=primary"
# )


# # Create the SQLAlchemy connection. Note that you need to have pyathena installed for this.
# engine = create_engine(
#     conn_str.format(
#         aws_access_key_id=quote_plus(AWS_ACCESS_KEY),
#         aws_secret_access_key=quote_plus(AWS_SECRET_KEY),
#         region_name=AWS_REGION,
#         schema_name=SCHEMA_NAME,
#         s3_staging_dir=quote_plus(S3_STAGING_DIR),
#     )
# )

# conn = engine.connect()

# %%
# pyathena connection
conn = connect(
    aws_access_key_id=AWS_ACCESS_KEY,
    aws_secret_access_key=AWS_SECRET_KEY,
    s3_staging_dir=S3_STAGING_DIR,
    region_name=AWS_REGION,
    schema_name=SCHEMA_NAME,  # Optional: Specify the schema name
    
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-35fd3ce4b6b6> in <module>
#       1 # pyathena connection
#       2 conn = connect(
# ----> 3     aws_access_key_id=AWS_ACCESS_KEY,
#       4     aws_secret_access_key=AWS_SECRET_KEY,
#       5     s3_staging_dir=S3_STAGING_DIR,
#
# NameError: name 'AWS_ACCESS_KEY' is not defined

# %%
query = 'SHOW TABLES IN yelp'
tables = pd.read_sql(query, conn)

tables
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-7de2c792c5fb> in <module>
#       1 query = 'SHOW TABLES IN yelp'
# ----> 2 tables = pd.read_sql(query, conn)
#       3
#       4 tables
#
# NameError: name 'conn' is not defined

# %%
query_business = """
        SELECT * 
        FROM yelp.businesses
        """

df = pd.read_sql(query_business, conn)

df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-ccc58c8d0330> in <module>
#       4         """
#       5
# ----> 6 df = pd.read_sql(query_business, conn)
#       7
#       8 df
#
# NameError: name 'conn' is not defined

# %%
df.to_csv("business_table.csv", index=False )

# %%
import geocoder

# Obtain GPS coordinates based on address or location
g = geocoder.osm("Portland, NM")
q_lat = g.lat
q_lon = g.lng
q = (q_lat, q_lon)
print("Latitude:", q_lat)
print("Longitude:", q_lon)
# Out:
# Latitude: 32.2918956
# Longitude: -106.802413

# %%
from geopy.distance import geodesic

# %%
def distance_to_q(coord1, q=q):
    return geodesic(coord1, q).miles

# %%
df_sample = df.sample(100)

# %%
df.apply(lambda row: distance_to_q((row.latitude, row.longitude), q), axis=1).sort_values
# Out:
# 65448     1267.773896
# 8567       239.110778
# 147131    1840.158190
# 15569     1043.752928
# 47273     1468.622582
#              ...
# 135358    1258.666025
# 28306     1476.085438
# 105758    1478.180117
# 91606     1467.244211
# 50738     1479.001655
# Length: 100, dtype: float64

# %%
def search_by_location_and_cuisine_type(location, cuisine_type="", n_results=20, df=df):
    coordinates = geocoder.osm(location)
    q = (coordinates.lat, coordinates.lng)
    print(q)
    cuisine_filter = df["categories"].str.split(", ").explode().str.lower().str.contains(cuisine_type.lower()).dropna()
    df_filtered = df.loc[cuisine_filter[cuisine_filter].index]
    print("filtered")
    distances = df_filtered.apply(lambda row: distance_to_q((row.latitude, row.longitude), q), axis=1).sort_values()
    result = df_filtered.loc[distances.index].head(n_results)
    result["distance"] = distances.head(n_results)
    return result, distances, coordinates

# %%
res, d, g= search_by_location_and_cuisine_type("Philadelphia, PA", "Mexican")
res
# Out:
# (39.9527237, -75.1635262)
# filtered
#                    business_id                    name  \
# 89795   0ZQVSAC4uwZR1JXmDrh9CQ               Taco Bell
# 69903   S21Myaj831l5rG4AKEyekA               Dos Tacos
# 132958  6F-6mFFNw2YXN7lD_Gukcg                  Lolita
# 37555   85e8Uyn8tIyEZCqBP80rqA                  Lolita
# 146673  n38QafGVzbdjavNHtCcpqA     12th Street Cantina
# 74809   9PZxjhTIU7OgPIzuGi89Ew                  El Vez
# 122648  G9LZoNlCfRH941q87_JLIg        Mission Taqueria
# 145620  o4gT7fMheja86ur9PVb2Iw           District Taco
# 28682   4rhH2r1lL7ujqnvTwZo--w  Chipotle Mexican Grill
# 71491   DvyG9Fx1EeNJfr_UNL7NYA         Fresco Tortilla
# 119641  tIrRQBpPou-WfYc0XkLVfA                   Sueno
# 140055  sixH4iwDJPWAPSId1qpxNw        Rosewood Tex-Mex
# 97209   bMMf5bjTAT8LrwhE84ZuNw  Chipotle Mexican Grill
# 81188   RAucBixPYsidSxjtl6VioQ    Mexican Post Express
# 76462   7Y3RjSc99a88oTMEgvazoA      QDOBA Mexican Eats
# 58989   rhdzgIxt3PikpHXm_QNCew             Animo Juice
# 43008   dXvNGmR8gGmHheK5gLHvkw            Mexican Post
# 25725   iegiacdW0vbAuKjb7FYFfg  Chipotle Mexican Grill
# 147996  EhPoBZIeHCfrFPl3Rqcg-Q              Wrap Shack
# 104017  xOCVsyNHR5Rjhx3ZVDJNnQ   Moe's Southwest Grill
#
# 81188   {alcohol=u'full_bar', businessacceptscreditcar...
# 76462   {alcohol='none', businessacceptscreditcards=Tr...
# 58989   {alcohol=u'none', businessacceptscreditcards=T...
# 43008   {alcohol='full_bar', businessacceptscreditcard...
# 25725   {alcohol=u'none', businessacceptscreditcards=T...
# 147996  {alcohol=u'full_bar', businessacceptscreditcar...
# 104017  {hastv=True, noiselevel=u'quiet', outdoorseati...
#
#                                                categories  \
# 89795            Tex-Mex, Restaurants, Mexican, Fast Food
# 69903                                Mexican, Restaurants
# 132958                               Restaurants, Mexican
# 37555                                Restaurants, Mexican
# 146673                               Restaurants, Mexican
# 74809   Lounges, Bars, Nightlife, Breakfast & Brunch, ...
# 122648  Tex-Mex, Restaurants, Food, Nightlife, Beer, W...
# 145620                               Restaurants, Mexican
# 28682                     Restaurants, Mexican, Fast Food
# 71491   Event Planning & Services, Restaurants, Mexica...
# 119641  Cocktail Bars, Nightlife, Restaurants, Mexican...
# 140055                      Restaurants, Tex-Mex, Mexican
# 97209               Fast Food, Mexican, Restaurants, Food
# 81188       Print Media, Mexican, Restaurants, Mass Media
# 76462   Restaurants, Mexican, Event Planning & Service...
# 58989   Restaurants, Vegan, Food, Juice Bars & Smoothi...
# 43008                                Mexican, Restaurants
# 25725                     Fast Food, Restaurants, Mexican
# 147996  Restaurants, Sports Bars, Bars, Mexican, Night...
# 104017                     Restaurants, Mexican, Southern
#
#                                                     hours  distance
# 89795                                                None  0.104765
# 69903   {"saturday":"11:0-15:0","tuesday":"11:0-21:0",...  0.191126
# 132958  {"sunday":"17:0-0:0","saturday":"17:0-0:0","tu...  0.196466
# 37555   {"sunday":"16:0-21:0","saturday":"12:0-22:0","...  0.199535
# 146673  {"sunday":"8:0-18:0","saturday":"8:0-18:0","tu...  0.220585
# 74809   {"sunday":"12:0-22:0","saturday":"16:0-22:0","...  0.228376
# 122648  {"saturday":"11:0-23:0","tuesday":"11:0-22:0",...  0.235857
# 145620  {"sunday":"10:0-17:0","saturday":"10:0-21:0","...  0.244007
# 28682   {"sunday":"12:0-18:0","saturday":"11:0-19:0","...  0.250712
# 71491   {"tuesday":"9:0-17:0","wednesday":"9:0-17:0","...  0.252888
# 119641  {"sunday":"16:0-23:0","saturday":"16:0-23:0","...  0.258829
# 140055                                               None  0.273472
# 97209   {"sunday":"10:45-22:0","saturday":"10:45-22:0"...  0.274398
# 81188   {"saturday":"8:0-17:0","tuesday":"8:0-19:0","w...  0.281515
# 76462   {"sunday":"11:0-21:0","saturday":"12:0-21:0","...  0.294776
# 58989   {"tuesday":"8:0-16:0","wednesday":"8:0-17:0","...  0.295207
# 43008   {"sunday":"15:0-20:0","saturday":"12:0-23:0","...  0.304072
# 25725   {"sunday":"10:45-22:0","saturday":"10:45-22:0"...  0.315165
# 147996  {"sunday":"11:0-21:30","saturday":"11:0-2:0","...  0.330902
# 104017  {"sunday":"11:0-18:0","saturday":"11:0-21:0","...  0.333291

# %%
res
